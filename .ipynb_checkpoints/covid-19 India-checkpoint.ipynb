# %%
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import datetime as dt
import numpy as np

# %%
#importing main dataset 
df = pd.read_csv('states.csv')

# %%
df.head()
# Out:
#          Date   State  Confirmed  Recovered  Deceased  Other  Tested
# 0  2020-01-30  Kerala          1          0         0      0     NaN
# 1  2020-01-30   India          1          0         0      0     NaN
# 2  2020-02-02  Kerala          2          0         0      0     NaN
# 3  2020-02-02   India          2          0         0      0     NaN
# 4  2020-02-03  Kerala          3          0         0      0     NaN

# %%
#keeping only required columns
df = df[['Date','State','Confirmed','Recovered', 'Deceased']]
#renaming column names
df.columns = ['date', 'state', 'confirmed','recovered','deceased']

# %%
df.head()
# Out:
#          date   state  confirmed  recovered  deceased
# 0  2020-01-30  Kerala          1          0         0
# 1  2020-01-30   India          1          0         0
# 2  2020-02-02  Kerala          2          0         0
# 3  2020-02-02   India          2          0         0
# 4  2020-02-03  Kerala          3          0         0

# %%
df.tail()
# Out:
#              date          state  confirmed  recovered  deceased
# 15685  2021-05-22        Tripura      45220      37369       454
# 15686  2021-05-22          India   26528977   23418836    299299
# 15687  2021-05-22  Uttar Pradesh    1665176    1551716     18978
# 15688  2021-05-22    Uttarakhand     310469     241430      5734
# 15689  2021-05-22    West Bengal    1248668    1102772     14208

# %%
#current date
today = df[df.date == '2021-05-22']
today
# Out:
#              date                                     state  confirmed  \
# 15653  2021-05-22               Andaman and Nicobar Islands       6820
# 15654  2021-05-22                            Andhra Pradesh    1562060
# 15655  2021-05-22                         Arunachal Pradesh      23867
# 15656  2021-05-22                                     Assam     365620
# 15657  2021-05-22                                     Bihar     685574
# 15658  2021-05-22                                Chandigarh      58129
# 15659  2021-05-22                              Chhattisgarh     945694
# 15660  2021-05-22                                     Delhi    1415219
# 15661  2021-05-22  Dadra and Nagar Haveli and Daman and Diu       9856
# 15662  2021-05-22                                       Goa     144839
# 15663  2021-05-22                                   Gujarat     784676
# 15664  2021-05-22                          Himachal Pradesh     177725
# ...

# %%
#Sorting data w.r.t number of confirmed cases
max_confirmed_cases=today.sort_values(by="confirmed",ascending=False)
max_confirmed_cases
# Out:
#              date                                     state  confirmed  \
# 15686  2021-05-22                                     India   26528977
# 15672  2021-05-22                               Maharashtra    5553225
# 15668  2021-05-22                                 Karnataka    2398925
# 15669  2021-05-22                                    Kerala    2322147
# 15684  2021-05-22                                Tamil Nadu    1806861
# 15687  2021-05-22                             Uttar Pradesh    1665176
# 15654  2021-05-22                            Andhra Pradesh    1562060
# 15660  2021-05-22                                     Delhi    1415219
# 15689  2021-05-22                               West Bengal    1248668
# 15659  2021-05-22                              Chhattisgarh     945694
# 15681  2021-05-22                                 Rajasthan     909521
# 15663  2021-05-22                                   Gujarat     784676
# ...

# %%
#Getting states with maximum number of confirmed cases
top_states_confirmed=max_confirmed_cases[0:5]

# %%
#Making bar-plot for states with top confirmed cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="confirmed",data=top_states_confirmed,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of death cases
max_death_cases=today.sort_values(by="deceased",ascending=False)
max_death_cases
# Out:
#              date                                     state  confirmed  \
# 15686  2021-05-22                                     India   26528977
# 15672  2021-05-22                               Maharashtra    5553225
# 15668  2021-05-22                                 Karnataka    2398925
# 15660  2021-05-22                                     Delhi    1415219
# 15684  2021-05-22                                Tamil Nadu    1806861
# 15687  2021-05-22                             Uttar Pradesh    1665176
# 15689  2021-05-22                               West Bengal    1248668
# 15679  2021-05-22                                    Punjab     533973
# 15659  2021-05-22                              Chhattisgarh     945694
# 15654  2021-05-22                            Andhra Pradesh    1562060
# 15663  2021-05-22                                   Gujarat     784676
# 15681  2021-05-22                                 Rajasthan     909521
# ...

# %%
#Getting states with maximum number of death cases
top_states_death=max_death_cases[0:5]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="deceased",data=top_states_death,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of cured cases
max_cured_cases=today.sort_values(by="recovered",ascending=False)
max_cured_cases
# Out:
#              date                                     state  confirmed  \
# 15686  2021-05-22                                     India   26528977
# 15672  2021-05-22                               Maharashtra    5553225
# 15669  2021-05-22                                    Kerala    2322147
# 15668  2021-05-22                                 Karnataka    2398925
# 15687  2021-05-22                             Uttar Pradesh    1665176
# 15684  2021-05-22                                Tamil Nadu    1806861
# 15660  2021-05-22                                     Delhi    1415219
# 15654  2021-05-22                            Andhra Pradesh    1562060
# 15689  2021-05-22                               West Bengal    1248668
# 15659  2021-05-22                              Chhattisgarh     945694
# 15681  2021-05-22                                 Rajasthan     909521
# 15663  2021-05-22                                   Gujarat     784676
# ...

# %%
#Getting states with maximum number of cured cases
top_states_cured=max_cured_cases[0:5]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="recovered",data=top_states_cured,hue="state")
plt.show()

# %%
#Visualizing confirmed cases in uttar pradesh
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="",y="confirmed",data=up,color="g")
plt.show()

# %%
#UP
up = df[df.state == 'Uttar Pradesh']
up
# Out:
#              date          state  confirmed  recovered  deceased
# 23     2020-03-04  Uttar Pradesh          7          0         0
# 30     2020-03-05  Uttar Pradesh          8          0         0
# 37     2020-03-06  Uttar Pradesh          8          0         0
# 46     2020-03-07  Uttar Pradesh          8          0         0
# 55     2020-03-08  Uttar Pradesh          8          0         0
# ...           ...            ...        ...        ...       ...
# 15539  2021-05-18  Uttar Pradesh    1637663    1483249     18072
# 15576  2021-05-19  Uttar Pradesh    1644849    1502918     18352
# 15613  2021-05-20  Uttar Pradesh    1651530    1516508     18588
# 15650  2021-05-21  Uttar Pradesh    1659212    1534176     18760
# 15687  2021-05-22  Uttar Pradesh    1665176    1551716     18978
#
# [445 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="confirmed",data=up,color="g")
plt.show()

# %%
#Visualizing death cases in up
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="deceased",data=up,color="r")
plt.show()

# %%
#Visualizing recovered cases in up
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="recovered",data=up,color="r")
plt.show()

# %%
#Checking state-wise testing details
tests = pd.read_csv('state_tested.csv')
tests
# Out:
#        Updated_On                        State  \
# 0      17-04-2020  Andaman and Nicobar Islands
# 1      24-04-2020  Andaman and Nicobar Islands
# 2      27-04-2020  Andaman and Nicobar Islands
# 3      01-05-2020  Andaman and Nicobar Islands
# 4      16-05-2020  Andaman and Nicobar Islands
# ...           ...                          ...
# 13608  19-05-2021                  West Bengal
# 13609  20-05-2021                  West Bengal
# 13610  21-05-2021                  West Bengal
# 13611  22-05-2021                  West Bengal
# 13612  23-05-2021                  West Bengal
#
#        RT-PCR Test(Includes TrueNat,CBNAAT,CRISPR) RAT(Rapid Antigen Test)  \
# 0                                              NaN                     NaN
# 1                                              NaN                     NaN
# 2                                              NaN                     NaN
# 3                                              NaN                     NaN
# ...

# %%
test_latest =  tests[tests.Updated_On == '22-05-2021']
test_latest
# Out:
#        Updated_On                        State  \
# 373    22-05-2021  Andaman and Nicobar Islands
# 782    22-05-2021               Andhra Pradesh
# 1181   22-05-2021            Arunachal Pradesh
# 1576   22-05-2021                        Assam
# 1988   22-05-2021                        Bihar
# 2389   22-05-2021                   Chandigarh
# 2793   22-05-2021                 Chhattisgarh
# 3377   22-05-2021                        Delhi
# 3782   22-05-2021                          Goa
# 4190   22-05-2021                      Gujarat
# 4603   22-05-2021                      Haryana
# 5012   22-05-2021             Himachal Pradesh
# 5422   22-05-2021            Jammu and Kashmir
# 5828   22-05-2021                    Jharkhand
# 6240   22-05-2021                    Karnataka
# 6658   22-05-2021                       Kerala
# 6875   22-05-2021                       Ladakh
# 6990   22-05-2021                  Lakshadweep
# 7403   22-05-2021               Madhya Pradesh
# ...

# %%
#Sorting data w.r.t number of cured cases
max_tests_State=test_latest.sort_values(by="Total Tested",ascending=False)
max_tests_State
# Out:
#        Updated_On                        State  \
# 12785  22-05-2021                Uttar Pradesh
# 7813   22-05-2021                  Maharashtra
# 1988   22-05-2021                        Bihar
# 6240   22-05-2021                    Karnataka
# 11664  22-05-2021                   Tamil Nadu
# 4190   22-05-2021                      Gujarat
# 6658   22-05-2021                       Kerala
# 3377   22-05-2021                        Delhi
# 782    22-05-2021               Andhra Pradesh
# 12004  22-05-2021                    Telangana
# 13611  22-05-2021                  West Bengal
# 9693   22-05-2021                       Odisha
# 10918  22-05-2021                    Rajasthan
# 1576   22-05-2021                        Assam
# 7403   22-05-2021               Madhya Pradesh
# 4603   22-05-2021                      Haryana
# 10506  22-05-2021                       Punjab
# 2793   22-05-2021                 Chhattisgarh
# 5422   22-05-2021            Jammu and Kashmir
# ...

# %%
#Making bar-plot for states with max test cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="State",y="Total Tested",data=max_tests_State[0:5],hue="State")
plt.show()

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
up
# Out:
#              date          state  confirmed  recovered  deceased
# 23     2020-03-04  Uttar Pradesh          7          0         0
# 30     2020-03-05  Uttar Pradesh          8          0         0
# 37     2020-03-06  Uttar Pradesh          8          0         0
# 46     2020-03-07  Uttar Pradesh          8          0         0
# 55     2020-03-08  Uttar Pradesh          8          0         0
# ...           ...            ...        ...        ...       ...
# 15539  2021-05-18  Uttar Pradesh    1637663    1483249     18072
# 15576  2021-05-19  Uttar Pradesh    1644849    1502918     18352
# 15613  2021-05-20  Uttar Pradesh    1651530    1516508     18588
# 15650  2021-05-21  Uttar Pradesh    1659212    1534176     18760
# 15687  2021-05-22  Uttar Pradesh    1665176    1551716     18978
#
# [445 rows x 5 columns]

# %%
from datetime import datetime
#converting date-time to ordinal
up['date']=up['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d')).map(dt.datetime.toordinal)
up.head()
# Out:
# <ipython-input-50-e3ffc88a74b9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up['date']=up['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d')).map(dt.datetime.toordinal)
#       date          state  confirmed  recovered  deceased
# 23  737488  Uttar Pradesh          7          0         0
# 30  737489  Uttar Pradesh          8          0         0
# 37  737490  Uttar Pradesh          8          0         0
# 46  737491  Uttar Pradesh          8          0         0
# 55  737492  Uttar Pradesh          8          0         0

# %%
#getting dependent variable and inpedent variable
x=up['date']
y=up['confirmed']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
up.tail()
# Out:
#          date          state  confirmed  recovered  deceased
# 15539  737928  Uttar Pradesh    1637663    1483249     18072
# 15576  737929  Uttar Pradesh    1644849    1502918     18352
# 15613  737930  Uttar Pradesh    1651530    1516508     18588
# 15650  737931  Uttar Pradesh    1659212    1534176     18760
# 15687  737932  Uttar Pradesh    1665176    1551716     18978

# %%
lr.predict(np.array([[737630]]))
# Out:
# array([[180080.04446864]])

# %%
# Define dates as strings
date_str1 = '23-05-2021'
date_str2 = '24-05-2021'
date_str3 = '25-05-2021'
date_str4 = '26-05-2021'
date_str5 = '27-05-2021'
date_str6 = '28-05-2021'
date_str7 = '29-05-2021'

# Define dates as datetime objects
date_dt1 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt2 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt3 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt4 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt5 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt6 = datetime.strptime(date_str3, '%d-%m-%Y')
date_dt7 = datetime.strptime(date_str3, '%d-%m-%Y')

predict_dt1 = lr.predict(np.array([[date_dt1]]))
predict_dt2 = lr.predict(np.array([[date_dt2]]))
predict_dt3 = lr.predict(np.array([[date_dt3]]))
predict_dt4 = lr.predict(np.array([[date_dt4]]))
predict_dt5 = lr.predict(np.array([[date_dt5]]))
predict_dt6 = lr.predict(np.array([[date_dt6]]))
predict_dt7 = lr.predict(np.array([[date_dt7]]))

# x axis values
x = [date_str1,date_str2,date_str3,date_str4,date_str5,date_str6,date_str7]
# corresponding y axis values
y = [predict_dt1, predict_dt2, predict_dt3, predict_dt4, predict_dt5, predict_dt6, predict_dt7]

# plotting the points
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3,
		marker='o', markerfacecolor='blue', markersize=12)

# setting x and y axis range
plt.ylim(1,8)
plt.xlim(1,8)

# naming the x axis
plt.xlabel('Date')
# naming the y axis
plt.ylabel('Confirmed Cases')

# giving a title to my graph
plt.title('Covid Prediction for Uttar Pradesh')

# function to show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-b84248edfd6e> in <module>
#      17 date_dt7 = datetime.strptime(date_str3, '%d-%m-%Y')
#      18
# ---> 19 predict_dt1 = lr.predict(np.array([[date_dt1]]))
#      20 predict_dt2 = lr.predict(np.array([[date_dt2]]))
#      21 predict_dt3 = lr.predict(np.array([[date_dt3]]))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# ...
